# %% [markdown]
# <a href="https://colab.research.google.com/github/LokiAndere/ML-tutties/blob/main/checkpoints.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.models import model_from_json
from keras.models import load_model
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
import keras.backend as BCKN
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
pd_path = '/content/drive/My Drive/DefectDetection/pima-indians-diabetes.csv'
dataset = np.loadtxt(pd_path, delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
print(dataset.shape)
print(dataset[:3])
# Out:
# (768, 9)
# [[  6.    148.     72.     35.      0.     33.6     0.627  50.      1.   ]
#  [  1.     85.     66.     29.      0.     26.6     0.351  31.      0.   ]
#  [  8.    183.     64.      0.      0.     23.3     0.672  32.      1.   ]]

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
BCKN.clear_session()
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 12)                108
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
filepath='/content/drive/My Drive/DefectDetection/weights.best.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.64173, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00002: val_accuracy did not improve from 0.64173
#
# Epoch 00003: val_accuracy did not improve from 0.64173
#
# Epoch 00004: val_accuracy did not improve from 0.64173
#
# Epoch 00005: val_accuracy did not improve from 0.64173
#
# Epoch 00006: val_accuracy did not improve from 0.64173
#
# Epoch 00007: val_accuracy did not improve from 0.64173
#
# Epoch 00008: val_accuracy did not improve from 0.64173
#
# Epoch 00009: val_accuracy did not improve from 0.64173
#
# Epoch 00010: val_accuracy did not improve from 0.64173
#
# Epoch 00011: val_accuracy did not improve from 0.64173
#
# Epoch 00012: val_accuracy did not improve from 0.64173
#
# Epoch 00013: val_accuracy improved from 0.64173 to 0.67323, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00014: val_accuracy did not improve from 0.67323
#
# Epoch 00015: val_accuracy did not improve from 0.67323
#
# Epoch 00016: val_accuracy did not improve from 0.67323
#
# Epoch 00017: val_accuracy did not improve from 0.67323
#
# Epoch 00018: val_accuracy did not improve from 0.67323
#
# Epoch 00019: val_accuracy did not improve from 0.67323
#
# Epoch 00020: val_accuracy did not improve from 0.67323
#
# Epoch 00021: val_accuracy did not improve from 0.67323
#
# Epoch 00022: val_accuracy did not improve from 0.67323
#
# Epoch 00023: val_accuracy did not improve from 0.67323
#
# Epoch 00024: val_accuracy did not improve from 0.67323
#
# Epoch 00025: val_accuracy did not improve from 0.67323
#
# Epoch 00026: val_accuracy improved from 0.67323 to 0.68504, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00027: val_accuracy did not improve from 0.68504
#
# Epoch 00028: val_accuracy did not improve from 0.68504
#
# Epoch 00029: val_accuracy did not improve from 0.68504
#
# Epoch 00030: val_accuracy did not improve from 0.68504
#
# Epoch 00031: val_accuracy did not improve from 0.68504
#
# Epoch 00032: val_accuracy did not improve from 0.68504
#
# Epoch 00033: val_accuracy did not improve from 0.68504
#
# Epoch 00034: val_accuracy did not improve from 0.68504
#
# Epoch 00035: val_accuracy did not improve from 0.68504
#
# Epoch 00036: val_accuracy improved from 0.68504 to 0.70079, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00037: val_accuracy did not improve from 0.70079
#
# Epoch 00038: val_accuracy did not improve from 0.70079
#
# Epoch 00039: val_accuracy did not improve from 0.70079
#
# Epoch 00040: val_accuracy did not improve from 0.70079
#
# Epoch 00041: val_accuracy did not improve from 0.70079
#
# Epoch 00042: val_accuracy did not improve from 0.70079
#
# Epoch 00043: val_accuracy improved from 0.70079 to 0.71260, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00044: val_accuracy improved from 0.71260 to 0.72047, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00045: val_accuracy did not improve from 0.72047
#
# Epoch 00046: val_accuracy did not improve from 0.72047
#
# Epoch 00047: val_accuracy did not improve from 0.72047
#
# Epoch 00048: val_accuracy did not improve from 0.72047
#
# Epoch 00049: val_accuracy did not improve from 0.72047
#
# Epoch 00050: val_accuracy did not improve from 0.72047
#
# Epoch 00051: val_accuracy did not improve from 0.72047
#
# Epoch 00052: val_accuracy did not improve from 0.72047
#
# Epoch 00053: val_accuracy did not improve from 0.72047
#
# Epoch 00054: val_accuracy did not improve from 0.72047
#
# Epoch 00055: val_accuracy did not improve from 0.72047
#
# Epoch 00056: val_accuracy did not improve from 0.72047
#
# Epoch 00057: val_accuracy did not improve from 0.72047
#
# Epoch 00058: val_accuracy did not improve from 0.72047
#
# Epoch 00059: val_accuracy did not improve from 0.72047
#
# Epoch 00060: val_accuracy did not improve from 0.72047
#
# Epoch 00061: val_accuracy did not improve from 0.72047
#
# Epoch 00062: val_accuracy did not improve from 0.72047
#
# Epoch 00063: val_accuracy did not improve from 0.72047
#
# Epoch 00064: val_accuracy did not improve from 0.72047
#
# Epoch 00065: val_accuracy did not improve from 0.72047
#
# Epoch 00066: val_accuracy did not improve from 0.72047
#
# Epoch 00067: val_accuracy did not improve from 0.72047
#
# Epoch 00068: val_accuracy improved from 0.72047 to 0.72835, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00069: val_accuracy did not improve from 0.72835
#
# Epoch 00070: val_accuracy did not improve from 0.72835
#
# Epoch 00071: val_accuracy did not improve from 0.72835
#
# Epoch 00072: val_accuracy did not improve from 0.72835
#
# Epoch 00073: val_accuracy improved from 0.72835 to 0.73622, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00074: val_accuracy did not improve from 0.73622
#
# Epoch 00075: val_accuracy did not improve from 0.73622
#
# Epoch 00076: val_accuracy did not improve from 0.73622
#
# Epoch 00077: val_accuracy did not improve from 0.73622
#
# Epoch 00078: val_accuracy did not improve from 0.73622
#
# Epoch 00079: val_accuracy did not improve from 0.73622
#
# Epoch 00080: val_accuracy did not improve from 0.73622
#
# Epoch 00081: val_accuracy did not improve from 0.73622
#
# Epoch 00082: val_accuracy improved from 0.73622 to 0.74409, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00083: val_accuracy did not improve from 0.74409
#
# Epoch 00084: val_accuracy did not improve from 0.74409
#
# Epoch 00085: val_accuracy did not improve from 0.74409
#
# Epoch 00086: val_accuracy did not improve from 0.74409
#
# Epoch 00087: val_accuracy improved from 0.74409 to 0.75197, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00088: val_accuracy did not improve from 0.75197
#
# Epoch 00089: val_accuracy did not improve from 0.75197
#
# Epoch 00090: val_accuracy did not improve from 0.75197
#
# Epoch 00091: val_accuracy did not improve from 0.75197
#
# Epoch 00092: val_accuracy did not improve from 0.75197
#
# Epoch 00093: val_accuracy did not improve from 0.75197
#
# Epoch 00094: val_accuracy did not improve from 0.75197
#
# Epoch 00095: val_accuracy did not improve from 0.75197
#
# Epoch 00096: val_accuracy did not improve from 0.75197
#
# Epoch 00097: val_accuracy did not improve from 0.75197
#
# Epoch 00098: val_accuracy did not improve from 0.75197
#
# Epoch 00099: val_accuracy did not improve from 0.75197
#
# Epoch 00100: val_accuracy did not improve from 0.75197
#
# Epoch 00101: val_accuracy did not improve from 0.75197
#
# Epoch 00102: val_accuracy did not improve from 0.75197
#
# Epoch 00103: val_accuracy did not improve from 0.75197
#
# Epoch 00104: val_accuracy did not improve from 0.75197
#
# Epoch 00105: val_accuracy did not improve from 0.75197
#
# Epoch 00106: val_accuracy did not improve from 0.75197
#
# Epoch 00107: val_accuracy did not improve from 0.75197
#
# Epoch 00108: val_accuracy did not improve from 0.75197
#
# Epoch 00109: val_accuracy improved from 0.75197 to 0.75591, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00110: val_accuracy did not improve from 0.75591
#
# Epoch 00111: val_accuracy did not improve from 0.75591
#
# Epoch 00112: val_accuracy did not improve from 0.75591
#
# Epoch 00113: val_accuracy did not improve from 0.75591
#
# Epoch 00114: val_accuracy did not improve from 0.75591
#
# Epoch 00115: val_accuracy did not improve from 0.75591
#
# Epoch 00116: val_accuracy did not improve from 0.75591
#
# Epoch 00117: val_accuracy did not improve from 0.75591
#
# Epoch 00118: val_accuracy did not improve from 0.75591
#
# Epoch 00119: val_accuracy did not improve from 0.75591
#
# Epoch 00120: val_accuracy did not improve from 0.75591
#
# Epoch 00121: val_accuracy did not improve from 0.75591
#
# Epoch 00122: val_accuracy did not improve from 0.75591
#
# Epoch 00123: val_accuracy did not improve from 0.75591
#
# Epoch 00124: val_accuracy did not improve from 0.75591
#
# Epoch 00125: val_accuracy improved from 0.75591 to 0.76378, saving model to /content/drive/My Drive/DefectDetection/weights.best.h5
#
# Epoch 00126: val_accuracy did not improve from 0.76378
#
# Epoch 00127: val_accuracy did not improve from 0.76378
#
# Epoch 00128: val_accuracy did not improve from 0.76378
#
# Epoch 00129: val_accuracy did not improve from 0.76378
#
# Epoch 00130: val_accuracy did not improve from 0.76378
#
# Epoch 00131: val_accuracy did not improve from 0.76378
#
# Epoch 00132: val_accuracy did not improve from 0.76378
#
# Epoch 00133: val_accuracy did not improve from 0.76378
#
# Epoch 00134: val_accuracy did not improve from 0.76378
#
# Epoch 00135: val_accuracy did not improve from 0.76378
#
# Epoch 00136: val_accuracy did not improve from 0.76378
#
# Epoch 00137: val_accuracy did not improve from 0.76378
#
# Epoch 00138: val_accuracy did not improve from 0.76378
#
# Epoch 00139: val_accuracy did not improve from 0.76378
#
# Epoch 00140: val_accuracy did not improve from 0.76378
#
# Epoch 00141: val_accuracy did not improve from 0.76378
#
# Epoch 00142: val_accuracy did not improve from 0.76378
#
# Epoch 00143: val_accuracy did not improve from 0.76378
#
# Epoch 00144: val_accuracy did not improve from 0.76378
#
# Epoch 00145: val_accuracy did not improve from 0.76378
#
# Epoch 00146: val_accuracy did not improve from 0.76378
#
# Epoch 00147: val_accuracy did not improve from 0.76378
#
# Epoch 00148: val_accuracy did not improve from 0.76378
#
# Epoch 00149: val_accuracy did not improve from 0.76378
#
# Epoch 00150: val_accuracy did not improve from 0.76378

# %%
def print_results(model, scores):
  print(f"{str(model.metrics_names[1])}: {scores[1]*100:.2f}%")

# %%
scores = model.evaluate(X, Y, verbose=0)
print_results(model,scores)
# Out:
# accuracy: 76.17%

# %%
json_path = '/content/drive/My Drive/DefectDetection/model.json'
model_json = model.to_json()
with open(json_path, 'w') as json_file:
    json_file.write(model_json)

weights_path = '/content/drive/My Drive/DefectDetection/model.h5'
model.save_weights(weights_path)

# %%
json_file = open(json_path, 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights(weights_path)

# %%
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
loaded_score = loaded_model.evaluate(X, Y, verbose=0)
print_results(loaded_model,loaded_score)
# Out:
# accuracy: 76.17%

# %%
all_together = '/content/drive/My Drive/DefectDetection/all_in_one_model.h5'
model.save(all_together)

# %%
full_loaded_model = load_model(all_together)
BCKN.clear_session()
full_loaded_model.summary()
scoreALLinONE = model.evaluate(X, Y, verbose=0)
print_results(full_loaded_model,scoreALLinONE)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 12)                108
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 76.17%

# %%
plot_model(model, to_file='/content/drive/My Drive/DefectDetection/model_plot.png', show_shapes=True, show_layer_names=True)
